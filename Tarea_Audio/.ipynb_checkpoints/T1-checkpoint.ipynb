# %%
import pyaudio
import wave
import matplotlib.pyplot as plt
import librosa
import soundfile as sf
import numpy as np
from IPython.display import Audio
from pydub import AudioSegment
import os

# %%
# !pip install ipython

# %%
filename = librosa.ex('humpback')

# %%
from IPython.display import Audio
# Import and display audio (sound) from URL
Audio(url="https://librosa.org/data/audio/glacier-bay-humpback.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="https://librosa.org/data/audio/glacier-bay-humpback.ogg" type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("https://github.com/husseinlopez/cdsi2024/raw/main/spring_in_my_step.mp3")
#Audio(url="https://github.com/librosa/data/blob/main/audio/glacier-bay-humpback.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
